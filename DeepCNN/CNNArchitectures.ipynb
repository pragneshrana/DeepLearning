# %% [markdown]
# <a href="https://colab.research.google.com/github/pragneshrana/DeepLearning/blob/master/DeepCNN/CNNArchitectures.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **For ImageNet Dataset**

# %% [markdown]
# # Alex Net

# %% [markdown]
# ![AlexNet_Summary_Table.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![AlexNet.png](data:image/png;base64,...)

# %% [markdown]
# # ZFNet

# %% [markdown]
# ![ZFNET.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # VGGNet

# %% [markdown]
# ![Screenshot from 2020-09-07 21-52-30.png](data:image/png;base64,...)

# %% [markdown]
# # What is 1 X 1 convolution filter?
#   - when depth of input $(D_I)$ is high
#   - Kernel of size(W X H = 1 X 1) is used to reduce the $(D_0 < D_I)$ depth.
#
#
# # What is output of maxpool with stride S=1, F=3, P=1?
#  - Same as original size

# %% [markdown]
# # GoogleNet
#  - Intution :
#     - Apply MANY SMALLER different size kernel in same layer
#     - TO reduce depth, apply 1X1 convolution filter

# %% [markdown]
# ![inception_module.png](data:image/png;base64,...)

# %% [markdown]
# **Full Architecture**

# %% [markdown]
# ![Screenshot from 2020-09-07 23-40-39.png](data:image/png;base64,...)

# %% [markdown]
# # ResNet (Residual Network)

# %% [markdown]
# ![Screenshot from 2020-09-08 00-34-45.png](data:image/png;base64,...)

# %% [markdown]
# Used for
#   - Classification
#   - Localization
#   - Object Detection
#   - Segmentation
