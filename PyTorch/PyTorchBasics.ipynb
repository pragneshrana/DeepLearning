# %% [markdown]
# <a href="https://colab.research.google.com/github/pragneshrana/DeepLearning/blob/master/PyTorch/PyTorchBasics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Initialise tensors

# %%
x = torch.ones(3,2)
print(x)
x = torch.rand(3,2)
print(x)
x = torch.zeros(3,2)
print(x)
# Out:
# tensor([[1., 1.],
#         [1., 1.],
#         [1., 1.]])
# tensor([[0.1576, 0.6572],
#         [0.2491, 0.7669],
#         [0.5869, 0.1996]])
# tensor([[0., 0.],
#         [0., 0.],
#         [0., 0.]])

# %%
x = torch.empty(3, 2)
print(x)
y = torch.zeros_like(x)
print(y)
# Out:
# tensor([[1.3435e-35, 0.0000e+00],
#         [3.3631e-44, 0.0000e+00],
#         [       nan, 0.0000e+00]])
# tensor([[0., 0.],
#         [0., 0.],
#         [0., 0.]])

# %%
x = torch.linspace(0, 1, steps=5)
print(x)
# Out:
# tensor([0.0000, 0.2500, 0.5000, 0.7500, 1.0000])

# %%
x = torch.tensor([[1, 2], 
                 [3, 4], 
                 [5, 6]])
print(x)
# Out:
# tensor([[1, 2],
#         [3, 4],
#         [5, 6]])

# %% [markdown]
# ## Slicing tensors

# %%
print(x.size())
print(x[:, 1]) 
print(x[0, :])
# Out:
# torch.Size([3, 2])
# tensor([2, 4, 6])
# tensor([1, 2])

# %%
y = x[1, 1]
print(y)
print(y.item())
# Out:
# tensor(4)
# 4

# %% [markdown]
# ## Reshaping tensors

# %%
print(x)
y = x.view(2, 3)
print(y)
# Out:
# tensor([[1, 2],
#         [3, 4],
#         [5, 6]])
# tensor([[1, 2, 3],
#         [4, 5, 6]])

# %%
y = x.view(6,-1) 
print(y)
# Out:
# tensor([[1],
#         [2],
#         [3],
#         [4],
#         [5],
#         [6]])

# %% [markdown]
# ## Simple Tensor Operations

# %%
x = torch.ones([3, 2])
y = torch.ones([3, 2])
z = x + y
print(z)
z = x - y
print(z)
z = x * y
print(z)
# Out:
# tensor([[2., 2.],
#         [2., 2.],
#         [2., 2.]])
# tensor([[0., 0.],
#         [0., 0.],
#         [0., 0.]])
# tensor([[1., 1.],
#         [1., 1.],
#         [1., 1.]])

# %%
z = y.add(x)
print(z)
print(y)
# Out:
# tensor([[2., 2.],
#         [2., 2.],
#         [2., 2.]])
# tensor([[1., 1.],
#         [1., 1.],
#         [1., 1.]])

# %%
z = y.add_(x) #inplace
print(z)
print(y)
# Out:
# tensor([[2., 2.],
#         [2., 2.],
#         [2., 2.]])
# tensor([[2., 2.],
#         [2., 2.],
#         [2., 2.]])

# %% [markdown]
# ## Numpy <> PyTorch

# %%
x_np = x.numpy()
print(type(x), type(x_np))
print(x_np)
# Out:
# <class 'torch.Tensor'> <class 'numpy.ndarray'>
# [[1. 1.]
#  [1. 1.]
#  [1. 1.]]

# %%
a = np.random.randn(5)
print(a)
a_pt = torch.from_numpy(a)
print(type(a), type(a_pt))
print(a_pt)
# Out:
# [ 1.62086179 -1.34767264 -1.5541624  -0.28404466 -1.3006683 ]
# <class 'numpy.ndarray'> <class 'torch.Tensor'>
# tensor([ 1.6209, -1.3477, -1.5542, -0.2840, -1.3007], dtype=torch.float64)

# %%
np.add(a, 1, out=a)
print(a)
print(a_pt)
# Out:
# [ 2.62086179 -0.34767264 -0.5541624   0.71595534 -0.3006683 ]
# tensor([ 2.6209, -0.3477, -0.5542,  0.7160, -0.3007], dtype=torch.float64)

# %%
# %%time
for i in range(100):
  a = np.random.randn(100,100)
  b = np.random.randn(100,100)
  c = np.matmul(a, b)
# Out:
# CPU times: user 165 ms, sys: 111 ms, total: 276 ms
# Wall time: 173 ms

# %%
# %%time
for i in range(100):
  a = torch.randn([100, 100])
  b = torch.randn([100, 100])
  c = torch.matmul(a, b)
# Out:
# CPU times: user 72.8 ms, sys: 77.4 ms, total: 150 ms
# Wall time: 102 ms

# %%
# %%time
for i in range(10):
  a = np.random.randn(10000,10000)
  b = np.random.randn(10000,10000)
  c = a + b
# Out:
# CPU times: user 1min 35s, sys: 1.42 s, total: 1min 37s
# Wall time: 1min 37s

# %%
# %%time
for i in range(10):
  a = torch.randn([10000, 10000])
  b = torch.randn([10000, 10000])
  c = a + b
# Out:
# CPU times: user 22.8 s, sys: 11.9 ms, total: 22.8 s
# Wall time: 22.8 s

# %% [markdown]
# ## CUDA support
# **Connect with GPU**

# %%
print(torch.cuda.device_count())
# Out:
# 1

# %%
print(torch.cuda.device(0))
print(torch.cuda.get_device_name(0))
# Out:
# ...
# Tesla T4

# %%
cuda0 = torch.device('cuda:0')

# %%
a = torch.ones(3, 2, device=cuda0)
b = torch.ones(3, 2, device=cuda0)
c = a + b
print(c)
# Out:
# tensor([[2., 2.],
#         [2., 2.],
#         [2., 2.]], device='cuda:0')

# %%
print(a)
# Out:
# tensor([[1., 1.],
#         [1., 1.],
#         [1., 1.]], device='cuda:0')

# %%
# %%time
for i in range(10):
  a = np.random.randn(10000,10000)
  b = np.random.randn(10000,10000)
  np.add(b, a)
# Out:
# CPU times: user 1min 21s, sys: 429 ms, total: 1min 21s
# Wall time: 1min 21s

# %%
# %%time
for i in range(10):
  a_cpu = torch.randn([10000, 10000])
  b_cpu = torch.randn([10000, 10000])
  b_cpu.add_(a_cpu)
# Out:
# CPU times: user 18.8 s, sys: 179 ms, total: 18.9 s
# Wall time: 19 s

# %%
# %%time
for i in range(10):
  a = torch.randn([10000, 10000], device=cuda0)
  b = torch.randn([10000, 10000], device=cuda0)
  b.add_(a)
# Out:
# CPU times: user 2.74 ms, sys: 4 µs, total: 2.75 ms
# Wall time: 7.58 ms

# %%
# %%time
for i in range(10):
  a = np.random.randn(10000,10000)
  b = np.random.randn(10000,10000)
  np.matmul(b, a)
# Out:
# CPU times: user 16min, sys: 3.77 s, total: 16min 4s
# Wall time: 8min 50s

# %%
# %%time
for i in range(10):
  a_cpu = torch.randn([10000, 10000])
  b_cpu = torch.randn([10000, 10000])
  torch.matmul(a_cpu, b_cpu)
# Out:
# CPU times: user 3min 51s, sys: 165 ms, total: 3min 51s
# Wall time: 3min 51s

# %%
# %%time
for i in range(10):
  a = torch.randn([10000, 10000], device=cuda0)
  b = torch.randn([10000, 10000], device=cuda0)
  torch.matmul(a, b)
# Out:
# CPU times: user 2.12 ms, sys: 3 ms, total: 5.12 ms
# Wall time: 11 ms

# %% [markdown]
# ## Autodiff

# %%
x = torch.ones([3, 2], requires_grad=True)
print(x)
# Out:
# tensor([[1., 1.],
#         [1., 1.],
#         [1., 1.]], requires_grad=True)

# %%
y = x + 5
print(y)
# Out:
# tensor([[6., 6.],
#         [6., 6.],
#         [6., 6.]], grad_fn=<AddBackward0>)

# %%
z = y*y + 1
print(z)
# Out:
# tensor([[37., 37.],
#         [37., 37.],
#         [37., 37.]], grad_fn=<AddBackward0>)

# %%
t = torch.sum(z)
print(t)
# Out:
# tensor(222., grad_fn=<SumBackward0>)

# %%
t.backward()

# %%
print(x.grad)
# Out:
# tensor([[12., 12.],
#         [12., 12.],
#         [12., 12.]])

# %% [markdown]
# $t = \sum_i z_i, z_i = y_i^2 + 1, y_i = x_i + 5$
#
# $\frac{\partial t}{\partial x_i} = \frac{\partial z_i}{\partial x_i} = \frac{\partial z_i}{\partial y_i} \frac{\partial y_i}{\partial x_i} = 2y_i \times 1$
#
#
# At x = 1, y = 6, $\frac{\partial t}{\partial x_i} = 12$

# %%
x = torch.ones([3, 2], requires_grad=True)
y = x + 5
r = 1/(1 + torch.exp(-y))
print(r)
s = torch.sum(r)
s.backward()
print(x.grad)
# Out:
# tensor([[0.9975, 0.9975],
#         [0.9975, 0.9975],
#         [0.9975, 0.9975]], grad_fn=<MulBackward0>)
# tensor([[0.0025, 0.0025],
#         [0.0025, 0.0025],
#         [0.0025, 0.0025]])

# %%
x = torch.ones([3, 2], requires_grad=True)
y = x + 5
r = 1/(1 + torch.exp(-y))
a = torch.ones([3, 2])
r.backward(a)
print(x.grad)
# Out:
# tensor([[0.0025, 0.0025],
#         [0.0025, 0.0025],
#         [0.0025, 0.0025]])

# %% [markdown]
# $\frac{\partial{s}}{\partial{x}} = \frac{\partial{s}}{\partial{r}} \cdot \frac{\partial{r}}{\partial{x}}$
#
# For the above code $a$ represents $\frac{\partial{s}}{\partial{r}}$ and then $x.grad$ gives directly $\frac{\partial{s}}{\partial{x}}$

# %% [markdown]
# ## Autodiff example that looks like what we have been doing

# %%
x = torch.randn([20, 1], requires_grad=True)
y = 3*x - 2

# %%
w = torch.tensor([1.], requires_grad=True)
b = torch.tensor([1.], requires_grad=True)

y_hat = w*x + b

loss = torch.sum((y_hat - y)**2)

# %%
print(loss)
# Out:
# tensor(306.5786, grad_fn=<SumBackward0>)

# %%
loss.backward()

# %%
print(w.grad, b.grad)
# Out:
# tensor([-86.9284]) tensor([146.4335])

# %% [markdown]
# ## Do it in a loop

# %%
learning_rate = 0.01

w = torch.tensor([1.], requires_grad=True)
b = torch.tensor([1.], requires_grad=True)

print(w.item(), b.item())

for i in range(10):
  
  x = torch.randn([20, 1])
  y = 3*x - 2
  
  #forward propogation
  y_hat = w*x + b
  loss = torch.sum((y_hat - y)**2)

  #backward prop
  loss.backward()
  
  # The wrapper "with torch.no_grad()" temporarily set all the requires_grad flag to false.
  # The book-keeping of gradient won't be cosidered further as just want to upgrade variablel
  # why? Make computation fast and no leakage of data 
  with torch.no_grad():
    w -= learning_rate * w.grad
    b -= learning_rate * b.grad

    #setting grad to zero
    w.grad.zero_()
    b.grad.zero_()

  print(w.item(), b.item())
# Out:
# 1.0 1.0
# 2.4877877235412598 -0.384097695350647
# 2.5985260009765625 -1.003037929534912
# 2.6017844676971436 -1.3569233417510986
# 2.8417465686798096 -1.6512740850448608
# 2.9086971282958984 -1.7801780700683594
# 2.92655611038208 -1.8661853075027466
# 2.987046003341675 -1.9336885213851929
# 2.984537363052368 -1.9589864015579224
# 2.9895081520080566 -1.974989891052246
# 2.9927451610565186 -1.9853358268737793

# %% [markdown]
# ## Do it for a large problem

# %%
# %%time
learning_rate = 0.001
N = 10000000
epochs = 200

w = torch.rand([N], requires_grad=True)
b = torch.ones([1], requires_grad=True)

# print(torch.mean(w).item(), b.item())

for i in range(epochs):
  
  x = torch.randn([N])
  y = torch.dot(3*torch.ones([N]), x) - 2
  
  y_hat = torch.dot(w, x) + b
  loss = torch.sum((y_hat - y)**2)
  
  loss.backward()
  
  with torch.no_grad():
    w -= learning_rate * w.grad
    b -= learning_rate * b.grad
    
    w.grad.zero_()
    b.grad.zero_()

#   print(torch.mean(w).item(), b.item())
# Out:
# CPU times: user 28.5 s, sys: 40.1 ms, total: 28.5 s
# Wall time: 28.5 s

# %%
# %%time
learning_rate = 0.001
N = 10000000
epochs = 200

w = torch.rand([N], requires_grad=True, device=cuda0)
b = torch.ones([1], requires_grad=True, device=cuda0)

# print(torch.mean(w).item(), b.item())

for i in range(epochs):
  
  x = torch.randn([N], device=cuda0)
  y = torch.dot(3*torch.ones([N], device=cuda0), x) - 2
  
  y_hat = torch.dot(w, x) + b
  loss = torch.sum((y_hat - y)**2)
  
  loss.backward()
  
  with torch.no_grad():
    w -= learning_rate * w.grad
    b -= learning_rate * b.grad
    
    w.grad.zero_()
    b.grad.zero_()

  #print(torch.mean(w).item(), b.item())
# Out:
# CPU times: user 447 ms, sys: 277 ms, total: 724 ms
# Wall time: 739 ms
