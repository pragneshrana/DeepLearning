# %% [markdown]
# <a href="https://colab.research.google.com/github/pragneshrana/DeepLearning/blob/master/SigmoidNeuron/ProbabilityTheory.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Intro :
#
# - For any event A, P(A) $\ge$ 1
# - For disjoint event $A_1, A_2, A_3, ... $and $A_i \cap A_j = \phi$ then $P(\cup A_i) = \sum_i P_i$
# - P(All events $\Omega$) = 1

# %% [markdown]
# # Random Variable
