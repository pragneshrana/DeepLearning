# %% [markdown]
# <a href="https://colab.research.google.com/github/pragneshrana/DeepLearning/blob/master/Common/gradient_descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Gradient Descent for Multiple regression

# %% [markdown]
# Hypothesis : $h(x)= \beta^TX = \beta_0 + \beta_1 x_1 + \beta_2 x_2+...+\beta_nx_n$<br>
# for m data points<br>,
# Cost fucntion: $J = \frac{1}{2m} \sum_{i=1}^{m}(h(x^{i}) - y^{i})^2$
#
# Algo: <br>
# Assume the parameter and increment by updating in each iteration,<br>
# $\beta_j :=  \beta_j - \alpha \dfrac{ \partial}{\partial \beta_j} J(\beta_0,\beta_1,\beta_2,...,\beta_n)$
# <br>
#
# By which we can obtain,<br>
# $\beta_j = \beta_j - \alpha \sum_{i=1}^{m}(h(x^{(i)})-y^{(i)})x_j^{(i)}$
# Here, for $i^{th}$ denotes data point and $j$ denotes features or columns
