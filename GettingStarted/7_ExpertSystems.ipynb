# %% [markdown]
# <a href="https://colab.research.google.com/github/pragneshrana/DeepLearning/blob/master/GettingStarted/ExpertSystems.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# How rule-based system can be used for binary classification?

# %% [markdown]
# # Why we need it?
# Given image task is to find out does it contains text or not..yes or no \\
# so, binary classification problem

# %% [markdown]
# # How human makes decision?
# - Based on several symptoms or combination of features (past experience)
#  1. features
#  2. rules

# %% [markdown]
# # How machine can make decision?
# - Converting the symptoms in to number machine unerstand the input and evetually make decision by processing the input

# %% [markdown]
# # 1.2

# %% [markdown]
# # limitation of Expert Systems
# - It is difficult to process lot of data
# - Rules might complex to processs
# - Some rule might be hard to express
# - Rules are unknown

# %% [markdown]
# # Why we need machine learning?
# To learn complex fucntion and find out its parameters (y=**f(x)**)

# %% [markdown]
# #  Data
# - text
# - video
# - audio, etc \\
# multi-model data

# %% [markdown]
# # why you need it?
# - to process review of product
# - catogrize problems
# - complete the data

# %% [markdown]
# #Elements of ML
# - Data
# - Task
#    1. Clustering
#    2. Generation
#    3. Person Identification
# - Models
#   1. y = f(x) $\leftarrow$ {true relation and unkown} \\
#     task is to find out the relationship between y ans x by learning the function\\
#   2. To estimate the parameter of different model are used like polynomial, sigmoid, Deep Neural Network(DNN), Deep convolutional Neural Network (DCNN), annd Recurrent Neural Network, etc.
#   3. Why not try complex function always? \\
#     Becuase of bias-variance trade off, overfitting.
# - Loss Function
#   1. How will we figure out which model/learnt function is better? //
#     By comapring the square error of the predicted value and actual value//
#     $\sum_{i=1}^{n} (y_i - \hat{f}(x_i))^2$ \\
#
#     Loss function gives insight about how good or bad my model is.
#
#     Types of loss function:\\
#     1. Square Error loss
#     2. Cross entropy loss
#     3. KL divergence
#
# - Learning Algorithms
#
#   1. How to learn parameters for models? \\
#   one way to use brute force like for ax1+bx2+c. \\
#   Now a$\in${-10,10}, b$\in${-50,50}, c$\in${-30,10} now by combination of all parmaeters (brute force) it is possible find optimum parameters such that loss function is minimized. But is cimplicated for high dimentional and computationally expennsive also.
#   2. Optimization Solvers/leanrning algorithms
#     1. Gradient Descent ++
#     2. Adagrad
#     3. RMSProp
#     4. Adam
#
#     Backpropogation and Backprogation training through time.
#
# - Evaluation (on the testing the data)
#   1. By calculating the accuracy of the model
#   3. Matric
#     1. Top-K accuracy
#     2. Precision, recall, F1
