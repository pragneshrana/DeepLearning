# %% [markdown]
# <a href="https://colab.research.google.com/github/pragneshrana/DeepLearning/blob/master/GettingStarted/PythonPackages.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Python Packages

# %%
import math

sqr = math.sqrt(100)
power = math.pow(100,0.5)

# %%
x = 100
y = 1
for i in range(1,x+1):
  y *= i
print('factorial of x',  'is ', y)
# Out:
# factorial of x is  93326215443944152681699238856266700490715968264381621468592963895217599993229915608941463976156518286253697920827223758251185210916864000000000000000000000000

# %%
y = math.factorial(x)

# %%
import math as m

# %%
from math import factorial

# %%
import time
val = list(range(1,100))
tic = time.time()
y = 1
for i in val:
  y *= i
print('factorial of x',  'is ', y)
toc = time.time()

print('elaplsed time :',toc-tic)
# Out:
# factorial of x is  933262154439441526816992388562667004907159682643816214685929638952175999932299156089414639761565182862536979208272237582511852109168640000000000000000000000
# elaplsed time : 0.00040340423583984375

# %%
import time
tic = time.time()
y = math.factorial(100)
toc = time.time()
print('factorial of x',  'is ', y)

print('elaplsed time :',toc-tic)
# Out:
# factorial of x is  93326215443944152681699238856266700490715968264381621468592963895217599993229915608941463976156518286253697920827223758251185210916864000000000000000000000000
# elaplsed time : 5.245208740234375e-05

# %%
# !echo 'def hello():' > my_module.py
# !echo '  print("hello! welcome come to the world of nerds")' >> my_module.py

# %%
# !cat my_module.py
# Out:
# def hello():
#   print("hello! welcome come to the world of nerds")

# %%
import my_module

# %%
my_module.hello()
# Out:
# hello! welcome come to the world of nerds
