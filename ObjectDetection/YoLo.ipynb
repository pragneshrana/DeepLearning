# %% [markdown]
# <a href="https://colab.research.google.com/github/pragneshrana/DeepLearning/blob/master/ObjectDetection/YoLo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### <center> YOLO : You Only Look Once

# %% [markdown]
# Drawback of RCNN:
# - Generate many regions around 2000 -> classification -> Regression -> correction : **Lot of Computations**

# %% [markdown]
# ### YOLO
#
# - Rather than dividing the image many segment divide the image into grids and based on confidence of each grid find out the region.

# %% [markdown]
# ![YOLO.png](data:image/png;base64,...)

# %% [markdown]
# - for each grid box, find confidence that it has object around it.
#
# - Output dimention : S X S X (5+K)

# %% [markdown]
# ![loss.png](data:image/png;base64,...)

# %% [markdown]
# $loss = \sum_{i=1}^M (L_c^i + L_w^i + L_h^i + L_x^i + L_y^i + L_{crossentropy})^2 $

# %% [markdown]
# Models : https://github.com/amusi/awesome-object-detection
